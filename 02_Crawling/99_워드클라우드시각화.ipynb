# %% [markdown]
# * https://drive.google.com/file/d/1todwi6NRInDwkFY24sSneP0c7RGTNTms/view?usp=sharing

# %% [markdown]
# #### konlpy 정상동작 확인

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\el91\appdata\local\programs\python\python311\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\el91\appdata\local\programs\python\python311\lib\site-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\el91\appdata\local\programs\python\python311\lib\site-packages (from konlpy) (6.0.2)
# Requirement already satisfied: numpy>=1.6 in c:\users\el91\appdata\local\programs\python\python311\lib\site-packages (from konlpy) (2.2.6)
# Requirement already satisfied: packaging in c:\users\el91\appdata\roaming\python\python311\site-packages (from JPype1>=0.7.0->konlpy) (25.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from konlpy.tag import Okt

okt = Okt()
print(okt.morphs("KoNLPy가 정상 설치되었는지 확인 중입니다."))
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# Cell In[3], line 3
#       1 from konlpy.tag import Okt
# ----> 3 okt = Okt()
#       4 print(okt.morphs("KoNLPy가 정상 설치되었는지 확인 중입니다."))
#
# File c:\Users\EL91\AppData\Local\Programs\Python\Python311\Lib\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# File c:\Users\EL91\AppData\Local\Programs\Python\Python311\Lib\site-packages\konlpy\jvm.py:55, in init_jvm(jvmpath, max_heap_size)
#      52 args = [javadir, os.sep]
#      53 classpath = [f.format(*args) for f in folder_suffix]
# ---> 55 jvmpath = jvmpath or jpype.getDefaultJVMPath()
#      57 # NOTE: Temporary patch for Issue #76. Erase when possible.
#      58 if sys.platform == 'darwin'\
#      59         and jvmpath.find('1.8.0') > 0\
#      60         and jvmpath.endswith('libjvm.dylib'):
#
# File c:\Users\EL91\AppData\Local\Programs\Python\Python311\Lib\site-packages\jpype\_jvmfinder.py:70, in getDefaultJVMPath()
#      68 else:
#      69     finder = LinuxJVMFinder()
# ---> 70 return finder.get_jvm_path()
#
# File c:\Users\EL91\AppData\Local\Programs\Python\Python311\Lib\site-packages\jpype\_jvmfinder.py:204, in JVMFinder.get_jvm_path(self)
#     202 if jvm_notsupport_ext is not None:
#     203     raise jvm_notsupport_ext
# --> 204 raise JVMNotFoundException("No JVM shared library file ({0}) "
#     205                            "found. Try setting up the JAVA_HOME "
#     206                            "environment variable properly."
#     207                            .format(self._libfile))
#
# JVMNotFoundException: No JVM shared library file (jvm.dll) found. Try setting up the JAVA_HOME environment variable properly.

# %%
import jpype
if not jpype.isJVMStarted():
    jpype.startJVM()
print("JPype와 JVM이 정상 작동 중입니다.")
# Out:
# JPype와 JVM이 정상 작동 중입니다.

# %%
import pandas as pd

# %% [markdown]
# #### 데이터 준비

# %%
# ------------------------------
#   파일 경로
# ------------------------------
data_file = 'data/네이버증권뉴스_2025-11-03.csv'

# ------------------------------
#   불러올 컬럼명
채금리       월스트리트     년 공백 지운 지드래곤  파워 에 관련   들썩  제 의  아파트    투자      망가질 결심  한가인 알고보니 카카오 식구였네  투자     엔씨소프트      에이치브이엠 유안타  주간추천주  뉴욕증시  고용 충격 외면하고 아마존에 주목 나스닥       마감 올해 개미 평균     손실   남은 두 달  반전 가능할까 밸류업      차별화 포인트가 없다    운용사들은 벌써 흥행 저조 걱정  분기 최대 실적 쓴 한화에어로  증권가 눈높이  쑥쑥   에너지 공룡  합병   이노 공식출항 재평가 기대 속 불확실성 여전  투자     네이버    코스메카코리아 하나  주간추천주   매해 아이폰    억개 폐기 수준     붐에 전자폐기물 넘쳐난다  비트코인이 미래다       급등한 이 기업  비트코인 더 산다 일본여행 가서 펑펑 또  슈퍼 엔저  가능성  개미는 두려운 이유  속보  고용쇼크  무시한 월스트리트 나스닥       전 세계가 들썩였는데 중국 증시는  트럼프 트레이드  없었다 부양책 쏟아내는 중국  이번엔 다르다는데   주식 지금이 매수 타이밍  뉴욕증시  아마존 실적에 고무 고용 지표 충격 소화 반등 출발  금감원  고려아연 유증 제동   명분 선      다음 스텝은   주간사모펀드 '

# %% [markdown]
# * 블용어 사전

# %%
# -----------------------
# 외부 불용어 사전
# -----------------------

import requests

url = "https://raw.githubusercontent.com/stopwords-iso/stopwords-ko/refs/heads/master/stopwords-ko.txt"
response = requests.get(url)

# 줄 단위로 나누고, 공백 제거 후 리스트 생성
external_stopwords = [line.strip() for line in response.text.splitlines() if line.strip()]

# -----------------------
# 커스터마이즈 불용어 사전
# -----------------------
custom_stopwords = []


# -----------------------
# 최종 불용어 사전
#   외부 불용어 사전, 커스터마이즈 불용어사전 합치고 중복 제거
# -----------------------
stopwords = set(external_stopwords + custom_stopwords)

# %% [markdown]
# #### 명사 추출 및 불용어 제거
# * KoNLPy라이브러리의 형태소분석기 사용
# * KoNLPy 사용 시 자바(JDK)가 필요할 수 있으니, 환경에 따라 JDK 설치 및 JAVA_HOME 환경변수 설정이 필요할 수도 있습니다​

# %%
# ----------------------------
# 형태소 분석기로 명사만 추출
# ----------------------------

from konlpy.tag import Okt

okt = Okt()
nouns = okt.nouns(clean_text)

# ----------------------------
# 한글자인 명사와 불용어 제거
# ----------------------------

filtered_nouns = [
    n for n in nouns
    if len(n) > 1 and n not in stopwords
]

# %% [markdown]
# #### 단어 빈도 계산
# * 리스트에서 각 항목이 몇 번 나오는지 카운트

# %%
from collections import Counter

counter = Counter(filtered_nouns)  # 명사 리스트를 Counter 객체로 변환
print(counter.most_common(10))
# Out:
# [('투자', 9), ('트럼프', 6), ('인텔', 6), ('엔비디아', 6), ('다우지수', 6), ('고용', 6), ('주식', 5), ('개미', 5), ('실적', 5), ('뉴욕증시', 5)]

# %% [markdown]
# #### 상위명사 추출

# %%
top50 = dict(counter.most_common(50))  # 가장 많이 등장한 50개 단어만 추출하여 딕셔너리 생성

# %% [markdown]
# #### 한글 폰트 설정 및 워드클라우드 시각화

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

font_path = 'C:\\Windows\\Fonts\\Hancom Gothic Regular.ttf'  # 한글 폰트 경로 (환경에 맞게 변경)
wc = WordCloud(font_path=font_path, background_color='white', width=800, height=600)

# 앞서 계산한 단어 빈도 사용하여 워드클라우드 생성
cloud = wc.generate_from_frequencies(top50)  # 또는 wc.generate_from_frequencies(counter) 전체 단어 사용

# 워드클라우드 이미지 시각화
plt.figure(figsize=(10, 8))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')  # 축 제거
plt.show()

# %%
from matplotlib import font_manager

# 시스템에 설치된 모든 폰트 리스트 가져오기
font_list = font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# 한글 폰트만 필터링 (이름에 'Malgun', 'Gothic', 'Nanum', 'Apple' 등 포함)
korean_fonts = [f for f in font_list if 'malgun' in f.lower() or
                                         'gothic' in f.lower() or
                                         'nanum' in f.lower() or
                                         'apple' in f.lower()]

# 결과 확인
for font in korean_fonts:
    print(font)
# Out:
# C:\Windows\Fonts\Hancom Gothic Bold.ttf
# C:\Windows\Fonts\malgunbd.ttf
# C:\Windows\Fonts\Hancom Gothic Regular.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareEB.otf
# C:\Windows\Fonts\GOTHIC.TTF
# C:\Windows\Fonts\NanumMyeongjoExtraBold.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumBarunpenB.otf
# C:\Windows\Fonts\malgunsl.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareB.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumBarunpenB.ttf
# C:\Windows\Fonts\NanumGothic.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\JalnanGothicTTF.ttf
# C:\Windows\Fonts\NanumGothicLight.ttf
# C:\Windows\Fonts\GOTHICI.TTF
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeo-eHv.ttf
# C:\Windows\Fonts\NanumBarunpenR.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeoOTF-Bd.otf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeoOTF-Rg.otf
# C:\Windows\Fonts\YES24GothicR.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeo-aLt.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeo-bRg.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumHaNaSonGeurSsi.ttf
# C:\Windows\Fonts\NanumGothicExtraBold.ttf
# C:\Windows\Fonts\NanumMyeongjo.ttf
# C:\Windows\Fonts\NanumGothicBold.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareEB.ttf
# C:\Windows\Fonts\malgun.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareB.otf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumBarunpenR.ttf
# C:\Windows\Fonts\NanumSquareR.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeoOTF-Hv.otf
# C:\Windows\Fonts\GOTHICB.TTF
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeo-cBd.ttf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeoOTF-Lt.otf
# C:\Windows\Fonts\NanumMyeongjoBold.ttf
# C:\Windows\Fonts\msgothic.ttc
# C:\Windows\Fonts\GOTHICBI.TTF
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\JalnanGothic.otf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeoOTF-Eb.otf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumBarunpenR.otf
# C:\Users\chopi\AppData\Local\Microsoft\Windows\Fonts\NanumSquareNeo-dEb.ttf

# %%
df = pd.read_csv(data_file)
df[df['title'].str.contains('비트코인')]['title']
# Out:
# 8           미 대선 사흘 앞으로… 비트코인 '2억원 꿈' 실현되나
# 31    트럼프 당선되면 얼마나 오를까…타오르는 비트코인 [투자의 재발견]
# 59    "비트코인이 미래다"…287% 급등한 이 기업, 비트코인 더 산다
# Name: title, dtype: object
